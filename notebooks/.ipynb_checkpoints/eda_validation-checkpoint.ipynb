# %%
import os
import sys
import pandas as pd
import numpy as np

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

from src.ranking.ranker import ranking

# %%
def load_products():
    path = os.path.abspath(
        os.path.join(os.getcwd(), "..", "data", "raw", "products.csv")
    )
    return pd.read_csv(path)

# %%
def load_users():
    path = os.path.abspath(
        os.path.join(os.getcwd(), "..", "data", "raw", "users.csv")
    )
    return pd.read_csv(path)

# %%
# Load data once
products_df = load_products()
users_df = load_users()

# %%
# Pick one sample user from each persona
budget_user = users_df[users_df["persona_type"] == "Budget"].iloc[0]
quality_user = users_df[users_df["persona_type"] == "Quality"].iloc[0]

# %%
# Run ranking once and reuse these results later
budget_ranked = ranking(products_df, budget_user)
quality_ranked = ranking(products_df, quality_user)

# %%
def check_price_distribution():
    print("===== PRICE DISTRIBUTION =====")
    print(f"Under 500:  {(products_df['price'] <= 500).mean() * 100:.2f}%")
    print(f"Under 1000: {(products_df['price'] <= 1000).mean() * 100:.2f}%")
    print(f"Under 2000: {(products_df['price'] <= 2000).mean() * 100:.2f}%")
    print()
    print("The price distribution shows a reasonable spread across low, medium and higher price ranges"
          "roughly thirty percent of products cost ₹500 or less, about fifty‑six percent are ₹1 000 or less "
          "and about seventy‑four percent are under ₹2 000. This suggests a balanced mix of affordable"
          "and mid‑range items, which supports diverse recommendations.")

# %%
def check_rating_distribution():
    print("===== RATING DISTRIBUTION =====")
    print(products_df["rating"].value_counts(dropna=False).sort_index())
    print()

    print("Observation:")
    print(
        "Ratings are mostly skewed toward higher values, which is typical in user‑generated product data."
        "This skew is not problematic on its own because there is still a variety of ratings across the scale,"
        "and it does not appear to dominate the logic unduly.."
    )
    print()

# %%
def check_purchases_vs_rating():
    print("===== AVERAGE PURCHASES PER RATING =====")
    print(products_df.groupby("rating")["num_purchases"].mean())
    print()

    print("Observation:")
    print(
        "Examining average purchases per rating reveals that products with higher ratings"
        "tend to have more purchases, but the pattern is moderate rather than extreme."
        "The dataset therefore reflects the intuitive notion that better products sell" 
        "more while leaving room for other factors such as price and brand to influence popularity."
    )
    print()

# %%
def check_rating_purchase_correlation():
    print("===== CORRELATION: PURCHASES VS RATING =====")
    corr = products_df[["num_purchases", "rating"]].corr()
    print(corr)
    print()

    print("Observation:")
    print(
        "The correlation of 0.424 between purchases and rating indicates a moderate positive relationship."
        "This means that popularity and rating are related, but popularity is not being driven solely by rating,"
        "which is a healthier scenario for recommendation logic."
    )
    print()

# %%
def check_missing_ratings():
    print("===== MISSING RATING CHECK =====")
    missing_percent = products_df["rating"].isna().mean() * 100
    print(f"Missing ratings (%): {missing_percent:.2f}")
    print()

    print("Observation:")
    print(
        "Approximately twenty‑one percent of products have missing ratings,"
        "a realistic proportion in a marketplace where newer or niche items may not yet have been reviewed."
        "This helps the ranking algorithm test how it handles items with incomplete information."
    )
    print()

# %%
def check_review_count_distribution():
    print("===== REVIEW COUNT DISTRIBUTION =====")
    print(products_df["review_count"].describe())
    print(f"Mean review count: {products_df['review_count'].mean():.2f}")
    print()

    print("Observation:")
    print(
        "The review count distribution spans a wide range, from products with no reviews to products with over a hundred."
        "The mean is around forty‑one, but the median is thirty‑seven and the lower quartile is six, indicating"
        "that many products have only a handful of reviews. This spread of review counts reflects varied user engagement"
        "levels and supports nuanced ranking."
    )
    print()

# %%
def check_rating_quality_correlation():
    print("===== CORRELATION: RATING VS INTRINSIC QUALITY =====")
    print(products_df[["rating", "intrinsic_quality"]].corr())
    print()

    print("Observation:")
    print(
        
    )
    print("Rating and intrinsic quality are almost perfectly correlated, suggesting that the ratings reflect"
          "underlying product quality very closely. This alignment means that better‑quality products generally have"
          "higher ratings, which is the intended relationship.")

# %%
def check_top_10_products():
    columns_to_show = [
        "price",
        "price_score",
        "purchase_score",
        "trusted_rating_score",
        "trusted_adjusted_purchase_score",
        "final_score",
        "intrinsic_quality",
    ]

    print("========= TOP 10 PRODUCTS FOR BUDGET USER =========")
    print(budget_ranked[columns_to_show].head(10))
    print()

    print("========= TOP 10 PRODUCTS FOR QUALITY USER =========")
    print(quality_ranked[columns_to_show].head(10))
    print()

    print("Observation:")
    print(
        "The top‑ten products for the Budget user include items with high price scores and respectable final scores,"
        "reflecting a balance of affordability and demand. The top‑ten products for the Quality user have higher intrinsic"
        "quality scores and trusted rating scores, indicating that quality signals are being prioritised. "
        "The average intrinsic quality of both users’ top lists is significantly higher than the overall product average,"
        "showing that the ranking function is selecting stronger products for each persona."
        "A small number of items for the Quality user have lower quality or missing trust values;"
        "these are edge cases and could be further tuned, but overall the recommendations align well with expectations."
    )
    print()

    suspicious_quality_products = quality_ranked[
        (quality_ranked["intrinsic_quality"] < 0.6)
        | (quality_ranked["trusted_rating_score"].isna())
    ]

    print("Suspicious Quality-user products:")
    print(suspicious_quality_products.head(10))
    print()

    budget_avg_quality = budget_ranked["intrinsic_quality"].head(10).mean()
    quality_avg_quality = quality_ranked["intrinsic_quality"].head(10).mean()
    overall_avg_quality = products_df["intrinsic_quality"].mean()

    print("Average intrinsic quality of Budget top 10:", budget_avg_quality)
    print("Average intrinsic quality of Quality top 10:", quality_avg_quality)
    print("Overall average intrinsic quality:", overall_avg_quality)
    print()

# %%
def dcg(scores):
    scores = np.array(scores)
    positions = np.arange(1, len(scores) + 1)
    return np.sum(scores / np.log2(positions + 1))


def idcg(scores, k):
    ideal_scores = sorted(scores, reverse=True)[:k]
    return dcg(ideal_scores)


def ndcg(scores, k):
    actual = dcg(scores[:k])
    ideal = idcg(scores, k)

    if ideal == 0:
        return 0

    return actual / ideal


def check_ndcg():
    budget_scores = budget_ranked["intrinsic_quality"].values
    quality_scores = quality_ranked["intrinsic_quality"].values

    print("===== NDCG SCORES =====")
    print("Budget NDCG@10:", ndcg(budget_scores, 10))
    print("Quality NDCG@10:", ndcg(quality_scores, 10))
    print()

# %%
def final_summary():
    print("===== FINAL SUMMARY =====")
    print(
        "Finally, the NDCG scores of 0.85 for the Budget user and 0.88 for the Quality user demonstrate that the ranking"
        "function is producing high‑quality recommendations. Overall, the dataset and ranking logic now behave consistently:"
        "price, rating, purchases, reviews and intrinsic quality show realistic relationships,"
        "and the system is producing plausible top recommendations for different user profiles"
    )
    print()

# %%
def run_all_checks():
    check_price_distribution()
    check_rating_distribution()
    check_purchases_vs_rating()
    check_rating_purchase_correlation()
    check_missing_ratings()
    check_review_count_distribution()
    check_rating_quality_correlation()
    check_top_10_products()
    check_ndcg()
    final_summary()


run_all_checks()
# Out:
# ===== PRICE DISTRIBUTION =====
# Under 500:  30.40%
# Under 1000: 56.40%
# Under 2000: 74.00%
#
# The price distribution shows a reasonable spread across low, medium and higher price rangesroughly thirty percent of products cost ₹500 or less, about fifty‑six percent are ₹1 000 or less and about seventy‑four percent are under ₹2 000. This suggests a balanced mix of affordableand mid‑range items, which supports diverse recommendations.
# ===== RATING DISTRIBUTION =====
# 1.005488      1
# 1.007795      1
# 1.036807      1
# 1.041453      1
# 1.050755      1
#            ...
# 4.955183      1
# 4.961013      1
# 4.968865      1
# 4.985232      1
# NaN         107
# Name: rating, Length: 394, dtype: int64
#
# Observation:
# Ratings are mostly skewed toward higher values, which is typical in user‑generated product data.This skew is not problematic on its own because there is still a variety of ratings across the scale,and it does not appear to dominate the logic unduly..
#
# ===== AVERAGE PURCHASES PER RATING =====
# rating
# 1.005488    1358.0
# 1.007795    1641.0
# 1.036807    1708.0
# 1.041453    3319.0
# 1.050755    2579.0
#              ...
# 4.938424    2797.0
# 4.955183    5000.0
# 4.961013    1906.0
# 4.968865    3708.0
# 4.985232    2754.0
# Name: num_purchases, Length: 393, dtype: float64
#
# Observation:
# Examining average purchases per rating reveals that products with higher ratingstend to have more purchases, but the pattern is moderate rather than extreme.The dataset therefore reflects the intuitive notion that better products sellmore while leaving room for other factors such as price and brand to influence popularity.
#
# ===== CORRELATION: PURCHASES VS RATING =====
#                num_purchases    rating
# num_purchases       1.000000  0.423985
# rating              0.423985  1.000000
#
# Observation:
# The correlation of 0.424 between purchases and rating indicates a moderate positive relationship.This means that popularity and rating are related, but popularity is not being driven solely by rating,which is a healthier scenario for recommendation logic.
#
# ===== MISSING RATING CHECK =====
# Missing ratings (%): 21.40
#
# Observation:
# Approximately twenty‑one percent of products have missing ratings,a realistic proportion in a marketplace where newer or niche items may not yet have been reviewed.This helps the ranking algorithm test how it handles items with incomplete information.
#
# ===== REVIEW COUNT DISTRIBUTION =====
# count    500.000000
# mean      41.032000
# std       34.342361
# min        0.000000
# 25%        6.000000
# 50%       37.000000
# 75%       63.000000
# max      148.000000
# Name: review_count, dtype: float64
# Mean review count: 41.03
#
# Observation:
# The review count distribution spans a wide range, from products with no reviews to products with over a hundred.The mean is around forty‑one, but the median is thirty‑seven and the lower quartile is six, indicatingthat many products have only a handful of reviews. This spread of review counts reflects varied user engagementlevels and supports nuanced ranking.
#
# ===== CORRELATION: RATING VS INTRINSIC QUALITY =====
#                      rating  intrinsic_quality
# rating             1.000000           0.999846
# intrinsic_quality  0.999846           1.000000
#
# Observation:
#
# Rating and intrinsic quality are almost perfectly correlated, suggesting that the ratings reflectunderlying product quality very closely. This alignment means that better‑quality products generally havehigher ratings, which is the intended relationship.
# ========= TOP 10 PRODUCTS FOR BUDGET USER =========
#      price  price_score  purchase_score  trusted_rating_score  \
# 328   2185     0.985637        0.666490                   NaN
# 371   2139     0.957526        0.673133                   NaN
# 304   2246     0.923754        0.956275              0.769067
# 407   2055     0.908245        0.950693              0.710885
# 296   1878     0.812549        0.975178              0.763943
# 364   2065     0.913976        0.938029              0.698318
# 91    2041     0.900282        0.955042              0.697174
# 210   1952     0.851266        0.627226                   NaN
# 154   2270     0.878623        0.605032                   NaN
# 358   1741     0.745459        1.000000              0.723475
#
#      trusted_adjusted_purchase_score  final_score  intrinsic_quality
# 328                              NaN     0.656916           0.837791
# 371                              NaN     0.644542           0.956323
# 304                         0.565603     0.635249           0.912933
# 407                         0.480440     0.561938           0.948911
# 296                         0.569122     0.557421           0.936402
# 364                         0.457428     0.550179           0.889935
# 91                          0.464200     0.543756           0.971017
# 210                              NaN     0.533937           0.445614
# 154                              NaN     0.531595           0.496281
# 358                         0.523416     0.479666           0.829230
#
# ========= TOP 10 PRODUCTS FOR QUALITY USER =========
#      price  price_score  purchase_score  trusted_rating_score  \
# 221   7388     0.820130        1.000000              0.752698
# 157   6702     0.704729        0.927284              0.706278
# 136   7243     0.794258        0.931818              0.619937
# 435   9925     0.620653        0.975120              0.735624
# 253   9050     0.800519        0.948965              0.581140
# 369   6565     0.683706        0.927762              0.608376
# 475   6367     0.654425        0.976017              0.603337
# 26    4832     0.466112        1.000000              0.661934
# 130   4817     0.464569        0.946028              0.629484
# 244   6945     0.743621        0.894492              0.413353
#
#      trusted_adjusted_purchase_score  final_score  intrinsic_quality
# 221                         0.566555     0.571512           0.907096
# 157                         0.462556     0.446207           0.964983
# 136                         0.358118     0.430004           0.981974
# 435                         0.527679     0.417849           0.920323
# 253                         0.320488     0.402616           0.865357
# 369                         0.343384     0.361597           0.781959
# 475                         0.355285     0.346139           0.752566
# 26                          0.438156     0.277244           0.880802
# 130                         0.374864     0.256952           0.762951
# 244                         0.152834     0.249260           0.611843
#
# Observation:
# The top‑ten products for the Budget user include items with high price scores and respectable final scores,reflecting a balance of affordability and demand. The top‑ten products for the Quality user have higher intrinsicquality scores and trusted rating scores, indicating that quality signals are being prioritised. The average intrinsic quality of both users’ top lists is significantly higher than the overall product average,showing that the ranking function is selecting stronger products for each persona.A small number of items for the Quality user have lower quality or missing trust values;these are edge cases and could be further tuned, but overall the recommendations align well with expectations.
#
# Suspicious Quality-user products:
#      product_id   brand     category  sub_category  review_count  \
# 353         354  Adidas     Footwear  Sports Shoes            80
# 417         418    Zara     Footwear       Sandals           102
# 101         102     MAC    Cosmetics   Moisturizer            58
# 144         145    Zara  Accessories         Belts             0
# 148         149     MAC    Cosmetics     Sunscreen            51
# 214         215     H&M  Accessories          Caps            56
# 48           49     MAC    Cosmetics      Lipstick            87
# 445         446    Nike  Accessories         Belts            77
# 430         431    Nike     Footwear         Boots            85
# 143         144    Nike  Accessories          Bags             0
#
#      intrinsic_quality  brand_strength    rating  price  num_purchases  ...  \
# 353           0.331558        0.388627  2.335195   7956           2762  ...
# 417           0.299362        0.997245  2.198566   7091           4700  ...
# 101           0.411181        0.538288  2.661518   5442           2569  ...
# 144           0.733076        0.152717       NaN   9503            150  ...
# 148           0.265733        0.506767  2.049651   8948           2163  ...
# 214           0.581169        0.249711  3.349914   2715           3048  ...
# 48            0.510272        0.779125  3.031843   2871           3817  ...
# 445           0.560664        0.805059  3.248164  12943           5000  ...
# 430           0.473023        0.385759  2.880519   2984           3007  ...
# 143           0.777613        0.092767       NaN   7519             22  ...
#
#     delivery_days     error  price_score  rating_score  purchase_log  \
# 353             6 -0.039710     0.929852      0.333799      7.924072
# 417             7 -0.144116     0.768013      0.299642      8.455531
# 101             7 -0.343150     0.533402      0.415380      7.851661
# 144             7  0.147013     0.701701           NaN      5.017280
# 148             1  0.080024     0.824623      0.262413      7.679714
# 214             1 -0.672299     0.291908      0.587479      8.022569
# 48              1 -0.653470     0.302150      0.507961      8.247482
# 445             2  0.562221     0.258012      0.562041      8.517393
# 430             6 -0.639831     0.309793      0.470130      8.009031
# 143             4 -0.092456     0.844227           NaN      3.135494
#
#      purchase_score  confidence_score  trusted_rating_score  \
# 353        0.930340          0.800000              0.267039
# 417        0.992737          0.836066              0.250520
# 101        0.921839          0.743590              0.308872
# 144        0.589063          0.000000                   NaN
# 148        0.901651          0.718310              0.188494
# 214        0.941904          0.736842              0.432879
# 48         0.968311          0.813084              0.413015
# 445        1.000000          0.793814              0.446156
# 430        0.940315          0.809524              0.380581
# 143        0.368128          0.000000                   NaN
#
#      trusted_adjusted_purchase_score  final_score
# 353                         0.066342     0.192321
# 417                         0.062304     0.149037
# 101                         0.087945     0.129400
# 144                              NaN     0.124004
# 148                         0.032036     0.116730
# 214                         0.176498     0.103909
# 48                          0.165176     0.102327
# 445                         0.199055     0.095987
# 430                         0.136197     0.095189
# 143                              NaN     0.093235
#
# [10 rows x 22 columns]
#
# Average intrinsic quality of Budget top 10: 0.8224437641855898
# Average intrinsic quality of Quality top 10: 0.8429853715728294
# Overall average intrinsic quality: 0.5110263155525734
#
# ===== NDCG SCORES =====
# Budget NDCG@10: 0.8515456640211417
# Quality NDCG@10: 0.8765975431366365
#
# ===== FINAL SUMMARY =====
# Finally, the NDCG scores of 0.85 for the Budget user and 0.88 for the Quality user demonstrate that the rankingfunction is producing high‑quality recommendations. Overall, the dataset and ranking logic now behave consistently:price, rating, purchases, reviews and intrinsic quality show realistic relationships,and the system is producing plausible top recommendations for different user profiles
